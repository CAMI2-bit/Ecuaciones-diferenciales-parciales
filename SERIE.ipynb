# %% [markdown]
# <a href="https://colab.research.google.com/github/CAMI2-bit/Ecuaciones-diferenciales-parciales/blob/main/SERIE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pylab import *

# %%
def recta(x):
    y = zeros(len(x))
    for i in range(len(x)):
        if i  < len(x)/2:
          y[i] = x[i]+2
        else:
          y[i] = 0 * x[i]
    return y

# %%
x = linspace(-2,2,1000)
f = recta(x)
plot(x,f,label='$f(x)$')
plt.xlabel('$x$'); plt.ylabel('$f(x)$');
plt.title("Gráfica de nuestra función definida a trozos")
xlim([-2.01,2.01]),ylim([-0.1,2.01]),grid(),legend()
show()

# %%
def u_0(x,N=20): # N es el número de armónicos
    f = zeros(len(x))
    for n in range(1,N):
        f += ((1-(-1)**n)/n**2)*cos(n*pi*x/2)-pi/n*sin(n*pi*x/2)
    return (2/pi**2)*f+1/2

# %%
f_n = u_0(x)
plot(x,f_n,label='$f(x)$ con $N=20$')
plot(x,f,label='$g(x)$')
plt.xlabel('$x$'); plt.ylabel('$f(x)$');
plt.title("Función definida a trozos y Serie de Fourier ")
xlim([-2.01,2.1]),ylim([-2.01,2.2]),grid(),legend()
show()

# %%
for i in range(1,20,5):
    plot(x,u_0(x,i),label='$g(x)$ con $N=%d$' %i)
plt.xlabel('$x$'); plt.ylabel('$f(x)$');
plt.title("Serie de Fourier con diferentes armónicos")
xlim([-2.01,2.01]),ylim([-2.01,2.2]),grid(),legend()
show()
